# %%
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
db_temp = pd.read_csv('C://Users//eduar//Desktop//DEV//Football//Brasileirao//database_temp.csv')
database = pd.read_csv('C://Users//eduar//Desktop//DEV//Football//Brasileirao//database.csv')

# Criando Backup
database.to_csv('C://Users//eduar//Desktop//DEV//Football//Brasileirao//database_bu.csv', index= False)

# Concatenando bases
db_final = pd.concat([database,db_temp], ignore_index= True)

# Tratamento de duplicadas
db_final = db_final.drop_duplicates(subset=['Jogador','Data'])

# %%
db_final
# Out:
#                      Jogador      Time   # Nação Pos.   Idade  Min.  Gols  \
# 0                       Éder  Criciúma  23   ITA   FW  37-150    57     0
# 1            Yannick Bolasie  Criciúma  11   COD   FW  34-325    33     0
# 2              Renato Kayser  Criciúma  79   BRA   FW  28-056    85     1
# 3                     Arthur  Criciúma  35   BRA   FW  31-303     5     0
# 4         Marquinhos Gabriel  Criciúma  10   BRA   AM  33-267    77     0
# ...                      ...       ...  ..   ...  ...     ...   ...   ...
# 8679                Reinaldo    Grêmio   6   BRA   LB  35-000    90     0
# 8680        Walter Kannemann    Grêmio   4   ARG   CB  33-198    90     0
# 8681  Gustavo Martins Santos    Grêmio  53   BRA   CB  22-048    90     0
# 8682              João Pedro    Grêmio  18   BRA   RB  27-318    90     0
# 8683       Agustín Marchesín    Grêmio   1   ARG   GK  36-196    90     0
#
#       Assis.  PB  PT  TC  CaG  CrtsA  CrtV  Contatos  Div  Crts  Bloqueios  \
# ...

# %%
db_final.to_csv('C://Users//eduar//Desktop//DEV//Football//LaLiga//database.csv', index= False)

# %%
db_final['Data'].unique()
# Out:
# array(['2024-04-13', '2024-04-14', '2024-04-17', '2024-04-16',
#        '2024-04-18', '2024-04-20', '2024-04-21', '2024-04-27',
#        '2024-04-28', '2024-04-29', '2024-05-04', '2024-05-05',
#        '2024-05-11', '2024-05-12', '2024-05-13', '2024-06-01',
#        '2024-06-02', '2024-06-05', '2024-06-09', '2024-06-11',
#        '2024-06-13', '2024-06-15', '2024-06-16', '2024-06-17',
#        '2024-06-19', '2024-06-20', '2024-06-22', '2024-06-23',
#        '2024-06-26', '2024-06-27', '2024-06-29', '2024-06-30',
#        '2024-07-01', '2024-07-03', '2024-07-04', '2024-07-06',
#        '2024-07-07', '2024-07-10', '2024-07-11', '2024-07-13',
#        '2024-07-16', '2024-07-17', '2024-07-20', '2024-07-21',
#        '2024-07-24', '2024-07-25', '2024-07-27', '2024-07-28',
#        '2024-08-03', '2024-08-04', '2024-08-05', '2024-08-10',
#        '2024-08-11', '2024-08-14', '2024-08-17', '2024-08-18',
#        '2024-08-19', '2024-08-24', '2024-08-25', '2024-08-26',
# ...
